# %%
# 1. 기본 데이터 처리, 정규식, 문자열처리 라이브러리
import numpy as np
import pandas as pd
import re
import string

# 2. 텍스트 처리 라이브러리
#from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
import konlpy
from konlpy.tag import Okt

# 3. 문자 빈도, 문자특성 추출, 워드클라우드
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from wordcloud import WordCloud

# 4. 데이터문서 및 날짜처리 라이브러리
from itertools import chain
import pickle
from datetime import datetime

# 5. 도표 및 시각화 라이브러리
import matplotlib.pyplot as plt
from matplotlib import font_manager
import networkx as nx
from networkx.drawing.nx_pydot import graphviz_layout

# %%
import sys
import datetime
import os
import requests
from bs4 import BeautifulSoup
import re
import pdb

# 작업 폴더 재설정(분석할 파일이나 corpus 있는 곳,)
WORK_HOME = r'C:\Users\Yun\Desktop\22 겨울방학\job'
os.chdir(WORK_HOME)   # 작업 폴더 이동 (UTagger 초기화: 사전 및 dll 라이브러리 interface 호출)

# %%
Data = pd.read_csv('job.csv', encoding='utf-8')

# %%
Data.head()
# Out:
#       회사명                   직무                                  링크  \
# 0  데이터라이즈     Backend Engineer   https://www.wanted.co.kr/wd/81841
# 1  데이터라이즈        Data Engineer   https://www.wanted.co.kr/wd/81834
# 2    데이터비  AI Engineer (ML/DL)   https://www.wanted.co.kr/wd/64852
# 3      윙잇         [윙잇] 데이터 분석가  https://www.wanted.co.kr/wd/133324
# 4   로이드케이    빅데이터 솔루션 데이터 엔지니어  https://www.wanted.co.kr/wd/144903
#
#                                                 자격요건  \
# 0  • 3년 이상의 실무 경험 또는 그에 준하는 이해도가 있으신 분 \n• 1개 이상의...
# 1  • 데이터 수집, 전처리 중 1개 이상 구축 경험이 있는 1년 이상의 경력자 또는 ...
# 2  - Python을 이용한 개발 경험 (pytorch, tensorflow, scik...
# 3  ■[이런 분과 함께하고 싶어요]\n• 데이터 분석 관련 경력 3년 이상 보유하신 분...
# 4  ㆍ서버 (Linux, Windows Server) 개념 이해 및 경험\nㆍDBMS ...
#
#                                                 우대사항
# 0  • 좋은 코드와 설계를 위한 고민 그리고 테스트의 중요성을 인지하고 계신 분\n• ...
# 1  • 좋은 코드와 설계를 위한 고민 그리고 테스트의 중요성을 인지하고 계신 분\n• ...
# 2  - 데이터와 소프트웨어 기술이 사람간의 의사소통을 더 원활하게 도울 수 있다고 믿는...
# 3  ■[이런 분이면 더욱 좋아요]\n• 프로그래밍 언어 구현 능력 있으신 분\n• 컴퓨...
# 4  ㆍ컴퓨터/정보통신/보안/시스템 공학계열 전공자\nㆍ정보처리(산업)기사, 리눅스마스터...

# %%
QR_K = Data['자격요건'].copy()
QR_E = Data['자격요건'].copy()

# %%
okt = konlpy.tag.Okt()

def clean_korean_documents(documents):

    for i, document in enumerate(documents):
            # 1. 텍스트 정제 (HTML 태그 제거)
            #document = BeautifulSoup(document, 'html.parser').text 

            # 2. 텍스트 정제 (특수기호 제거)
            #pdb.set_trace()
            document = re.sub(r'[^ ㄱ-ㅎㅣ가-힣]', ' ', document) # 한글, blank 외의 문자= > 제거특수기호 제거
            document = re.sub(r'(\s+)',' ', document)  # 연속적인 ' ' 를 하나로 

            # 3. 텍스트 정제 (형태소 추출)
            clean_words = []
            for word in okt.pos(document, stem=True): #어간 추출
                if word[1] in ['Noun', 'Adjective']: #명사, 형용사 okt.tagsets 참조
                    clean_words.append(word[0])
                    
            documents[i] = clean_words               # 이 경우 join 되지 않은 리스트 생성 ( ','로 구분 리스트)
    return documents

# %%
def clean_english_documents(documents):

    for i, document in enumerate(documents):
        
        # 영문자 이외 문자는 공백으로 변환
        document = re.sub(r'[^ a-zA-Z]+', '', document)  #영문 제외
        document = re.sub(r'(\s+)',' ', document)  # 연속적인 ' ' 를 하나로 


        # 소문자 변환
        no_capitals = document.lower().split()

        # 불용어 제거
        stops = set(stopwords.words('english'))
        no_stops = [word for word in no_capitals if not word in stops]
        
        
        documents[i] = no_stops
    return documents

# %%
# 전처리 기본 함수 적용하여 PrePrecessed_TEXT 데이터셋(리스트) 생성

Cleaned_QR_K = clean_korean_documents(QR_K)

# %%
Cleaned_QR_E = clean_english_documents(QR_E)

# %%
def lengthTxt(func):
    newTxt = []
    for doc in func:
        filteredTxt = [w for w in doc if len(w) > 1]
        newTxt.append(filteredTxt)
    return newTxt

# %%
Finished_QR_K = lengthTxt(Cleaned_QR_K)

# %%
# 3. 문자 빈도, 문자특성 추출, 워드클라우드
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
from itertools import chain

# %%
# stopword 제거
def replaceTxt(func, old, new):
    newList = []
    for doc in func:
        newTxt = []
        for w in doc:
            newTxt.append(w.replace(old, new))
        newList.append(newTxt)
    return newList

# %%
# 모든 리스트를 하나로 연결하여 어휘 빈도 count (최대 어휘수 지정)
print(Counter(list(chain.from_iterable(Finished_QR_K))).most_common(1000))
# Out:
# [('경험', 565), ('있다', 541), ('데이터', 474), ('이상', 334), ('분석', 300), ('경력', 228), ('개발', 225), ('대한', 201), ('능력', 155), ('이해', 143), ('관련', 140), ('보유', 134), ('가능하다', 131), ('활용', 130), ('운영', 117), ('사용', 112), ('역량', 112), ('업무', 108), ('서비스', 104), ('커뮤니케이션', 94), ('처리', 88), ('기반', 87), ('기술', 83), ('지식', 81), ('언어', 80), ('문제', 76), ('능숙하다', 70), ('다양하다', 70), ('구축', 69), ('환경', 66), ('해결', 65), ('설계', 54), ('관리', 51), ('가능', 47), ('통계', 47), ('결과', 47), ('프로젝트', 46), ('원활하다', 45), ('협업', 45), ('빠르다', 45), ('가지', 45), ('시스템', 44), ('비즈니스', 43), ('기획', 42), ('기본', 41), ('작성', 41), ('개선', 38), ('도출', 38), ('실무', 37), ('논리', 37), ('학력', 37), ('관심', 36), ('필수', 36), ('추출', 36), ('필요하다', 36), ('인사이트', 35), ('사고', 35), ('빅데이터', 34), ('이해도', 33), ('프로그래밍', 33), ('높다', 33), ('플랫폼', 32), ('용량', 31), ('클라우드', 31), ('데이터베이스', 31), ('러닝', 31), ('파이프라인', 30), ('무관', 30), ('통한', 30), ('유관', 29), ('주도', 29), ('사업', 29), ('분야', 28), ('통해', 28), ('고객', 27), ('하나', 27), ('모델링', 27), ('이렇다', 26), ('모바일', 26), ('가공', 26), ('진행', 26), ('계시다', 25), ('부서', 25), ('알고리즘', 25), ('모델', 24), ('익숙하다', 24), ('분산', 24), ('게임', 24), ('이용', 23), ('신입', 23), ('프로', 23), ('시각', 22), ('프레임워크', 22), ('졸업', 22), ('정의', 22), ('위해', 22), ('마케팅', 22), ('적용', 21), ('바탕', 21), ('학사', 21), ('공학', 21), ('가설', 21), ('문서', 21), ('지표', 21), ('새롭다', 21), ('보신', 20), ('전공', 20), ('지원', 20), ('코드', 19), ('동료', 19), ('없다', 19), ('디자인', 19), ('구조', 19), ('상황', 19), ('수립', 18), ('쿼리', 18), ('요건', 18), ('많다', 18), ('의견', 17), ('도구', 17), ('컴퓨터', 17), ('소통', 17), ('머신', 17), ('대졸', 17), ('엔지니어링', 17), ('수학', 17), ('덕트', 17), ('유연하다', 17), ('의사결정', 17), ('적극', 16), ('직접', 16), ('대해', 16), ('인프라', 16), ('복잡하다', 16), ('프로덕트', 16), ('수집', 15), ('고민', 15), ('구현', 15), ('프론트엔드', 15), ('포트폴리오', 15), ('제출', 15), ('산업', 15), ('의사소통', 15), ('수행', 15), ('프로세스', 15), ('스킬', 15), ('제품', 14), ('백엔드', 14), ('개발자', 14), ('스택', 14), ('이슈', 14), ('실험', 14), ('해당', 14), ('자기', 14), ('목표', 14), ('효과', 14), ('자동화', 14), ('우대', 14), ('책임감', 13), ('전략', 13), ('수준', 13), ('사용자', 13), ('명확하다', 13), ('솔루션', 13), ('도전', 13), ('구성원', 13), ('네트워크', 13), ('포함', 12), ('서버', 12), ('문제해결', 12), ('자격', 12), ('원하다', 12), ('열정', 12), ('성과', 12), ('대응', 12), ('학습', 12), ('핵심', 12), ('전달', 12), ('엔지니어', 12), ('검증', 12), ('좋다', 12), ('통계학', 12), ('년제', 12), ('제안', 12), ('학과', 11), ('정확하다', 11), ('프로그램', 11), ('의미', 11), ('직무', 11), ('전반', 11), ('소프트웨어', 11), ('기초', 11), ('성장', 11), ('자료구조', 11), ('책임', 11), ('같다', 10), ('학위', 10), ('자산', 10), ('변화', 10), ('전공자', 10), ('정제', 10), ('대시보드', 10), ('설정', 10), ('성장하다', 10), ('연구', 10), ('달성', 10), ('로스', 10), ('대학', 10), ('이하', 10), ('소지', 10), ('필요', 10), ('팀원', 10), ('아키텍처', 9), ('개념', 9), ('꼼꼼하다', 9), ('라이브러리', 9), ('리딩', 9), ('프로덕션', 9), ('테스트', 9), ('거나', 9), ('존중', 9), ('과정', 9), ('컴퓨터공학', 9), ('전산', 9), ('이상인', 9), ('로그', 9), ('방법', 9), ('적절하다', 9), ('선택', 9), ('경우', 9), ('추천', 9), ('과제', 9), ('태도', 9), ('실패', 9), ('로직', 9), ('두렵다', 9), ('기대하다', 9), ('원인', 9), ('실력', 8), ('실시간', 8), ('최적화', 8), ('디자이너', 8), ('사항', 8), ('최소', 8), ('행동', 8), ('영어', 8), ('숙련', 8), ('자유', 8), ('깊다', 8), ('스타트업', 8), ('설득', 8), ('직면', 8), ('중심', 8), ('적자', 8), ('신중하다', 8), ('병목', 8), ('해소', 8), ('반드시', 8), ('마주', 8), ('배치', 7), ('신분', 7), ('디지털', 7), ('긍정', 7), ('뛰어나다', 7), ('성능', 7), ('조직', 7), ('모니터링', 7), ('어떻다', 7), ('튜닝', 7), ('상품', 7), ('본인', 7), ('운영체제', 7), ('효율', 7), ('코호트', 7), ('퍼널', 7), ('버전', 7), ('마인드', 7), ('정보', 7), ('설명', 7), ('전문가', 7), ('실제', 7), ('외부', 7), ('가치', 7), ('병역', 7), ('결격', 7), ('사유', 7), ('해석', 7), ('예측', 7), ('소스', 7), ('어플리케이션', 7), ('정신', 7), ('초기', 7), ('집중', 7), ('소재', 7), ('기보', 7), ('근본', 7), ('주력', 7), ('겸손하다', 7), ('신뢰', 7), ('집요하다', 7), ('공유', 6), ('아래', 6), ('개인', 6), ('구성', 6), ('프레임', 6), ('아키텍쳐', 6), ('도메인', 6), ('화하다', 6), ('여러', 6), ('파이썬', 6), ('어려움', 6), ('내용', 6), ('석사', 6), ('근무', 6), ('텐션', 6), ('소개', 6), ('자료', 6), ('액션', 6), ('방법론', 6), ('요구사항', 6), ('핸들링', 6), ('포팅', 6), ('풍부하다', 6), ('광고', 6), ('자연어', 5), ('거부', 5), ('연동', 5), (' ...

# %%
Finished_QR_K = replaceTxt(Finished_QR_K, '있다', '')
Finished_QR_K = replaceTxt(Finished_QR_K, '이상', '')
Finished_QR_K = replaceTxt(Finished_QR_K, '대한', '')
Finished_QR_K = replaceTxt(Finished_QR_K, '활용', '')
Finished_QR_K = replaceTxt(Finished_QR_K, '능숙하다', '')
Finished_QR_K = replaceTxt(Finished_QR_K, '기본', '')
Finished_QR_K = replaceTxt(Finished_QR_K, '가지', '')
Finished_QR_K = replaceTxt(Finished_QR_K, '높다', '')
Finished_QR_K = replaceTxt(Finished_QR_K, '무관', '')
Finished_QR_K = replaceTxt(Finished_QR_K, '통한', '')
Finished_QR_K = replaceTxt(Finished_QR_K, '계시다', '')
Finished_QR_K = replaceTxt(Finished_QR_K, '많다', '')

# %%
print(Counter(list(chain.from_iterable(Cleaned_QR_E))).most_common(1000))
# Out:
# [('python', 128), ('sql', 105), ('java', 42), ('r', 39), ('data', 32), ('spark', 27), ('db', 22), ('linux', 20), ('aws', 20), ('mysql', 18), ('api', 18), ('tableau', 18), ('git', 17), ('hadoop', 17), ('scala', 17), ('tensorflow', 16), ('pytorch', 15), ('kafka', 15), ('react', 14), ('bi', 13), ('c', 13), ('cloud', 13), ('spring', 13), ('typescript', 12), ('airflow', 12), ('rdbms', 12), ('postgresql', 11), ('database', 11), ('framework', 11), ('google', 10), ('mldl', 10), ('pandas', 9), ('hive', 9), ('ab', 9), ('ml', 9), ('excel', 9), ('os', 9), ('go', 8), ('nosql', 8), ('oracle', 7), ('pm', 7), ('script', 7), ('analytics', 7), ('ai', 7), ('raw', 7), ('javascript', 6), ('nodejs', 6), ('adobe', 6), ('studio', 6), ('tool', 6), ('redash', 6), ('gcp', 6), ('shell', 6), ('index', 6), ('mongodb', 5), ('mssql', 5), ('dba', 5), ('etl', 5), ('redis', 5), ('elk', 5), ('rdb', 5), ('cohort', 5), ('flask', 5), ('cicd', 5), ('workflow', 5), ('cs', 5), ('django', 5), ('nlp', 5), ('scikitlearn', 4), ('dbms', 4), ('vuejs', 4), ('jira', 4), ('apache', 4), ('github', 4), ('aarrr', 4), ('web', 4), ('ga', 4), ('quicksight', 4), ('numpy', 4), ('system', 4), ('boot', 4), ('jvm', 4), ('eg', 4), ('join', 4), ('ui', 4), ('vue', 4), ('http', 4), ('bc', 3), ('windows', 3), ('server', 3), ('restful', 3), ('elasticsearch', 3), ('matlab', 3), ('backend', 3), ('engineering', 3), ('frontend', 3), ('swift', 3), ('devops', 3), ('test', 3), ('amplitude', 3), ('kubernetes', 3), ('ltv', 3), ('da', 3), ('native', 3), ('superset', 3), ('cc', 3), ('application', 3), ('centos', 3), ('power', 3), ('azure', 3), ('language', 3), ('etlelt', 3), ('hbase', 3), ('ecosystem', 3), ('kotlinjava', 3), ('modeling', 3), ('golang', 3), ('bigquery', 3), ('athena', 3), ('qa', 3), ('sas', 3), ('open', 3), ('tcpip', 3), ('mes', 3), ('log', 3), ('uxui', 3), ('transformation', 2), ('wpf', 2), ('socket', 2), ('monday', 2), ('siem', 2), ('glue', 2), ('kinesis', 2), ('redshift', 2), ('bigdata', 2), ('platform', 2), ('machine', 2), ('learning', 2), ('crm', 2), ('notion', 2), ('slack', 2), ('flex', 2), ('nextjs', 2), ('reactjs', 2), ('aidata', 2), ('ios', 2), ('firebase', 2), ('nginx', 2), ('ecs', 2), ('docker', 2), ('figma', 2), ('zeplin', 2), ('streaming', 2), ('flink', 2), ('sqlrpythonspark', 2), ('analysis', 2), ('dl', 2), ('migration', 2), ('ppt', 2), ('fastapi', 2), ('pipeline', 2), ('prefect', 2), ('oozie', 2), ('etc', 2), ('kpi', 2), ('macos', 2), ('msoffice', 2), ('analyst', 2), ('scientist', 2), ('powerbi', 2), ('engineer', 2), ('nodejstypescriptjavascript', 2), ('html', 2), ('unixlinux', 2), ('mariadb', 2), ('ex', 2), ('springspring', 2), ('mongo', 2), ('dbredis', 2), ('sw', 2), ('jpa', 2), ('jsp', 2), ('uiux', 2), ('javascripttypescript', 2), ('laravel', 2), ('photoshop', 2), ('illustrator', 2), ('msa', 2), ('design', 2), ('product', 2), ('sqlpython', 2), ('pmfproductmarket', 2), ('fit', 2), ('iteration', 2), ('hr', 2), ('databricks', 2), ('si', 2), ('sales', 2), ('orm', 2), ('query', 2), ('programming', 2), ('springboot', 2), ('presto', 2), ('vision', 2), ('funnel', 2), ('mart', 2), ('feature', 2), ('keras', 2), ('olap', 2), ('bb', 2), ('rpython', 2), ('source', 2), ('ittech', 2), ('fps', 2), ('pcmobile', 2), ('sqlmysqlmssql', 2), ('user', 2), ('visualization', 2), ('lake', 2), ('sklearn', 2), ('dw', 2), ('public', 2), ('aiml', 2), ('backup', 2), ('digital', 1), ('htmlcssjqueryjavascript', 1), ('xd', 1), ('net', 1), ('restwebsocket', 1), ('angular', 1), ('sap', 1), ('soar', 1), ('emr', 1), ('pythonjavashell', 1), ('panda', 1), ('dblog', 1), ('hadoopelasticsearch', 1), ('sparkehiveimpala', 1), ('etlextract', 1), ('load', 1), ('kafak', 1), ('influxdb', 1), ('mongdb', 1), ('insight', 1), ('salesforce', 1), ('workspace', 1), ('lemonbase', 1), ('reactcontext', 1), ('stitchesreact', 1), ('nestjs', 1), ('typeorm', 1), ('ruby', 1), ('rails', 1), ('postman', 1), ('gat', 1), ('nodevec', 1), ('scikit', 1), ('spacy', 1), ('bokeh', 1), ('dvc', 1), ('reactnative', 1), ('reactorkit', 1), ('rxswif ...

# %%
Finished_QR = Finished_QR_K + Cleaned_QR_E
# Out:
# C:\Users\Yun\anaconda3\lib\site-packages\pandas\core\roperator.py:9: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return right + left

# %%
print(Counter(list(chain.from_iterable(Finished_QR))).most_common(1000))
# Out:
# [('', 1498), ('경험', 565), ('데이터', 474), ('분석', 300), ('경력', 228), ('개발', 225), ('능력', 155), ('이해', 143), ('관련', 140), ('보유', 134), ('가능하다', 131), ('python', 128), ('운영', 117), ('사용', 112), ('역량', 112), ('업무', 108), ('sql', 105), ('서비스', 104), ('커뮤니케이션', 94), ('처리', 88), ('기반', 87), ('기술', 83), ('지식', 81), ('언어', 80), ('문제', 76), ('다양하다', 70), ('구축', 69), ('환경', 66), ('해결', 65), ('설계', 54), ('관리', 51), ('가능', 47), ('통계', 47), ('결과', 47), ('프로젝트', 46), ('원활하다', 45), ('협업', 45), ('빠르다', 45), ('시스템', 44), ('비즈니스', 43), ('기획', 42), ('java', 42), ('작성', 41), ('r', 39), ('개선', 38), ('도출', 38), ('실무', 37), ('논리', 37), ('학력', 37), ('관심', 36), ('필수', 36), ('추출', 36), ('필요하다', 36), ('인사이트', 35), ('사고', 35), ('빅데이터', 34), ('이해도', 33), ('프로그래밍', 33), ('플랫폼', 32), ('data', 32), ('용량', 31), ('클라우드', 31), ('데이터베이스', 31), ('러닝', 31), ('파이프라인', 30), ('유관', 29), ('주도', 29), ('사업', 29), ('분야', 28), ('통해', 28), ('고객', 27), ('하나', 27), ('spark', 27), ('모델링', 27), ('이렇다', 26), ('모바일', 26), ('가공', 26), ('진행', 26), ('부서', 25), ('알고리즘', 25), ('모델', 24), ('익숙하다', 24), ('분산', 24), ('게임', 24), ('이용', 23), ('신입', 23), ('프로', 23), ('시각', 22), ('db', 22), ('프레임워크', 22), ('졸업', 22), ('정의', 22), ('위해', 22), ('마케팅', 22), ('적용', 21), ('바탕', 21), ('학사', 21), ('공학', 21), ('가설', 21), ('문서', 21), ('지표', 21), ('새롭다', 21), ('보신', 20), ('linux', 20), ('전공', 20), ('지원', 20), ('aws', 20), ('코드', 19), ('동료', 19), ('없다', 19), ('디자인', 19), ('구조', 19), ('상황', 19), ('mysql', 18), ('수립', 18), ('쿼리', 18), ('api', 18), ('요건', 18), ('tableau', 18), ('의견', 17), ('도구', 17), ('컴퓨터', 17), ('소통', 17), ('git', 17), ('머신', 17), ('대졸', 17), ('hadoop', 17), ('엔지니어링', 17), ('scala', 17), ('수학', 17), ('덕트', 17), ('유연하다', 17), ('의사결정', 17), ('적극', 16), ('직접', 16), ('tensorflow', 16), ('대해', 16), ('인프라', 16), ('복잡하다', 16), ('프로덕트', 16), ('수집', 15), ('고민', 15), ('pytorch', 15), ('구현', 15), ('프론트엔드', 15), ('포트폴리오', 15), ('제출', 15), ('kafka', 15), ('산업', 15), ('의사소통', 15), ('수행', 15), ('프로세스', 15), ('스킬', 15), ('제품', 14), ('백엔드', 14), ('개발자', 14), ('스택', 14), ('react', 14), ('이슈', 14), ('실험', 14), ('해당', 14), ('자기', 14), ('목표', 14), ('효과', 14), ('자동화', 14), ('우대', 14), ('bi', 13), ('책임감', 13), ('전략', 13), ('c', 13), ('수준', 13), ('사용자', 13), ('cloud', 13), ('명확하다', 13), ('솔루션', 13), ('도전', 13), ('구성원', 13), ('네트워크', 13), ('spring', 13), ('포함', 12), ('서버', 12), ('문제해결', 12), ('typescript', 12), ('자격', 12), ('원하다', 12), ('airflow', 12), ('열정', 12), ('성과', 12), ('대응', 12), ('학습', 12), ('핵심', 12), ('전달', 12), ('엔지니어', 12), ('검증', 12), ('좋다', 12), ('통계학', 12), ('rdbms', 12), ('년제', 12), ('제안', 12), ('postgresql', 11), ('학과', 11), ('정확하다', 11), ('프로그램', 11), ('의미', 11), ('직무', 11), ('database', 11), ('전반', 11), ('소프트웨어', 11), ('기초', 11), ('성장', 11), ('자료구조', 11), ('책임', 11), ('framework', 11), ('같다', 10), ('학위', 10), ('자산', 10), ('변화', 10), ('google', 10), ('전공자', 10), ('정제', 10), ('대시보드', 10), ('설정', 10), ('성장하다', 10), ('연구', 10), ('달성', 10), ('로스', 10), ('mldl', 10), ('대학', 10), ('이하', 10), ('소지', 10), ('필요', 10), ('팀원', 10), ('아키텍처', 9), ('개념', 9), ('꼼꼼하다', 9), ('라이브러리', 9), ('pandas', 9), ('리딩', 9), ('hive', 9), ('프로덕션', 9), ('테스트', 9), ('ab', 9), ('ml', 9), ('거나', 9), ('존중', 9), ('excel', 9), ('과정', 9), ('컴퓨터공학', 9), ('전산', 9), ('os', 9), ('인', 9), ('로그', 9), ('방법', 9), ('적절하다', 9), ('선택', 9), ('경우', 9), ('추천', 9), ('과제', 9), ('태도', 9), ('실패', 9), ('로직', 9), ('두렵다', 9), ('기대하다', 9), ('원인', 9), ('실력', 8), ('실시간', 8), ('최적화', 8), ('디자이너', 8), ('사항', 8), ('최소', 8), ('행동', 8), ('go', 8), ('여러', 8), ('nosql', 8), ('영어', 8), ('숙련', 8), ('자유', 8), ('깊다', 8), ('스타트업', 8), ('설득', 8), ('직면', 8), ('중심', 8), ('적자', 8), ('신중하다', 8), ('병목', 8), ('해소', 8), ('반드시', 8), ('마주', 8), ('배치', 7), ('oracle', 7), ('pm', 7), ('신분', 7), ('script', 7), ('디지털', 7), ('긍정', 7), ('뛰어나다', 7), ('성능', 7), ('analytics', 7), ('조직', 7), ('모니터링', 7), ('어떻다', 7), ('튜닝', 7), ('상품', 7), ('본인', 7), ('운영체제', 7), ('효율', 7), ('ai', 7), ('코호트', 7), ('퍼널', 7), ('버전', 7), ('마인드', 7), ('정보', 7), ('설명', 7), ('전문가', 7), ('raw', 7), ('실제', 7), ('외부 ...

# %%
# 문서별 선정된 어휘를 하나의 문장으로 연결
def joinTxt(func):
    newTxt = []
    for doc in func:
        newTxt.append(" ".join(doc))
    return newTxt

# %%
# 함수 적용
Finished_QR_JOIN = joinTxt(Finished_QR)

# %%
import pickle

with open('Finished_QR.bin', 'wb') as fp:
    pickle.dump(Finished_QR, fp)

# %%
import pickle

with open('Finished_QR_JOIN.bin', 'wb') as fp:
    pickle.dump(Finished_QR_JOIN, fp)

# %%
# 전처리 완료된 데이터 중 조인(join)된 데이터 불러오기
with open('Finished_QR_JOIN.bin', 'rb') as fp:
    qr_ko_word = pickle.load(fp)

# %%
cv=CountVectorizer(max_features=200)
dtm=cv.fit_transform(qr_ko_word)
words=cv.get_feature_names()
# Out:
# C:\Users\Yun\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# 1. 단어 합계계산
# 2. 2차원을 1차원으로 변경(squeeze)
# 3. 단어명-단어빈도 결합
# 4. 빈도 높은 순으로 sort
count_mat=dtm.sum(axis=0)     # term 별 합계
count=np.squeeze(np.asarray(count_mat))   # squeeze 함수:배열의 모양에서 단일 차원 항목을 삭제 => 1차원 배열
word_count=list(zip(words,count))
word_count=sorted(word_count, key=lambda x:x[1], reverse=True)   # 단어 빈도별 내림 차순 정렬 
word_count
# Out:
# [('경험', 565),
#  ('데이터', 474),
#  ('분석', 300),
#  ('경력', 228),
#  ('개발', 225),
#  ('능력', 155),
#  ('이해', 143),
#  ('관련', 140),
#  ('보유', 134),
#  ('가능하다', 131),
#  ('python', 128),
#  ('운영', 117),
#  ('사용', 112),
#  ('역량', 112),
#  ('업무', 108),
#  ('sql', 105),
#  ('서비스', 104),
#  ('커뮤니케이션', 94),
#  ('처리', 88),
#  ('기반', 87),
#  ('기술', 83),
#  ('지식', 81),
#  ('언어', 80),
#  ('문제', 76),
#  ('다양하다', 70),
#  ('구축', 69),
#  ('환경', 66),
#  ('해결', 65),
#  ('설계', 54),
#  ('관리', 51),
#  ('가능', 47),
#  ('결과', 47),
#  ('통계', 47),
#  ('프로젝트', 46),
#  ('빠르다', 45),
#  ('원활하다', 45),
#  ('협업', 45),
#  ('시스템', 44),
#  ('비즈니스', 43),
#  ('java', 42),
#  ('기획', 42),
#  ('작성', 41),
#  ('개선', 38),
#  ('도출', 38),
#  ('논리', 37),
#  ('실무', 37),
#  ('학력', 37),
#  ('관심', 36),
#  ('추출', 36),
#  ('필수', 36),
#  ('필요하다', 36),
#  ('사고', 35),
#  ('인사이트', 35),
#  ('빅데이터', 34),
#  ('이해도', 33),
#  ('프로그래밍', 33),
#  ('data', 32),
#  ('플랫폼', 32),
#  ('데이터베이스', 31),
#  ('러닝', 31),
#  ('용량', 31),
#  ('클라우드', 31),
#  ('파이프라인', 30),
#  ('사업', 29),
#  ('유관', 29),
#  ('주도', 29),
#  ('분야', 28),
#  ('통해', 28),
#  ('spark', 27),
#  ('고객', 27),
#  ('모델링', 27),
#  ('하나', 27),
#  ('가공', 26),
#  ('모바일', 26),
#  ('이렇다', 26),
#  ('진행', 26),
#  ('부서', 25),
#  ('알고리즘', 25),
#  ('게임', 24),
#  ('모델', 24),
#  ('분산', 24),
#  ('익숙하다', 24),
#  ('신입', 23),
#  ('이용', 23),
#  ('프로', 23),
#  ('db', 22),
#  ('마케팅', 22),
#  ('시각', 22),
#  ('위해', 22),
#  ('정의', 22),
#  ('졸업', 22),
#  ('프레임워크', 22),
#  ('가설', 21),
#  ('공학', 21),
#  ('문서', 21),
#  ('바탕', 21),
#  ('새롭다', 21),
#  ('적용', 21),
#  ('지표', 21),
#  ('학사', 21),
#  ('aws', 20),
#  ('linux', 20),
#  ('보신', 20),
#  ('전공', 20),
#  ('지원', 20),
#  ('구조', 19),
#  ('동료', 19),
#  ('디자인', 19),
#  ('상황', 19),
#  ('없다', 19),
#  ('코드', 19),
#  ('api', 18),
#  ('mysql', 18),
#  ('tableau', 18),
#  ('수립', 18),
#  ('요건', 18),
#  ('쿼리', 18),
#  ('git', 17),
#  ('hadoop', 17),
#  ('scala', 17),
#  ('대졸', 17),
#  ('덕트', 17),
#  ('도구', 17),
#  ('머신', 17),
#  ('소통', 17),
#  ('수학', 17),
#  ('엔지니어링', 17),
#  ('유연하다', 17),
#  ('의견', 17),
#  ('의사결정', 17),
#  ('컴퓨터', 17),
#  ('tensorflow', 16),
#  ('대해', 16),
#  ('복잡하다', 16),
#  ('인프라', 16),
#  ('적극', 16),
#  ('직접', 16),
#  ('프로덕트', 16),
#  ('kafka', 15),
#  ('pytorch', 15),
#  ('고민', 15),
#  ('구현', 15),
#  ('산업', 15),
#  ('수집', 15),
#  ('수행', 15),
#  ('스킬', 15),
#  ('의사소통', 15),
#  ('제출', 15),
#  ('포트폴리오', 15),
#  ('프로세스', 15),
#  ('프론트엔드', 15),
#  ('react', 14),
#  ('개발자', 14),
#  ('목표', 14),
#  ('백엔드', 14),
#  ('스택', 14),
#  ('실험', 14),
#  ('우대', 14),
#  ('이슈', 14),
#  ('자기', 14),
#  ('자동화', 14),
#  ('제품', 14),
#  ('해당', 14),
#  ('효과', 14),
#  ('bi', 13),
#  ('cloud', 13),
#  ('spring', 13),
#  ('구성원', 13),
#  ('네트워크', 13),
#  ('도전', 13),
#  ('명확하다', 13),
#  ('사용자', 13),
#  ('솔루션', 13),
#  ('수준', 13),
#  ('전략', 13),
#  ('책임감', 13),
#  ('airflow', 12),
#  ('rdbms', 12),
#  ('typescript', 12),
#  ('검증', 12),
#  ('년제', 12),
#  ('대응', 12),
#  ('문제해결', 12),
#  ('서버', 12),
#  ('성과', 12),
#  ('엔지니어', 12),
#  ('열정', 12),
#  ('원하다', 12),
#  ('자격', 12),
#  ('전달', 12),
#  ('제안', 12),
#  ('좋다', 12),
#  ('통계학', 12),
#  ('포함', 12),
#  ('학습', 12),
#  ('핵심', 12),
#  ('framework', 11),
#  ('기초', 11),
#  ('자료구조', 11),
#  ('프로그램', 11)]

# %%
# 워드클라우드 시각화 
wc=WordCloud(font_path='C:/Windows/Fonts/malgun.ttf', background_color='black', width=1200, height=800)
cloud=wc.generate_from_frequencies(dict(word_count))

plt.figure(figsize=(12,12))
plt.imshow(cloud)
plt.axis('off')
plt.show()
